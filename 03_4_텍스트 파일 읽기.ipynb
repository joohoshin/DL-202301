# %% [markdown]
# 파이썬에서 데이터를 불러올때는 Pandas 라이브러리를 많이 사용합니다.
#
# Pandas의 DataFrame은 엑셀 시트와 유사하다고 볼 수 있으며, 엑셀 및 SQL에서 가능한 대부분의 연산을 지원합니다.
#
# 파일, Database, 웹 등 다양한 소스에서 데이터를 불러올 수 있습니다.
#
# https://pandas.pydata.org/docs/user_guide/io.html
#
# 또한, 데이터 전처리에 필요한 많은 기능을 제공합니다

# %% [markdown]
# CSV 파일 읽기
#
# 아래 파일을 다운받아서 읽어들여봅시다
#
# https://www.kaggle.com/datasets/ulrikthygepedersen/co2-emissions-by-country

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/Teaching/DL 202301/co2_emissions_kt_by_country.csv')

# %%
df.head()
# Out:
#   country_code country_name  year      value
# 0          ABW        Aruba  1960  11092.675
# 1          ABW        Aruba  1961  11576.719
# 2          ABW        Aruba  1962  12713.489
# 3          ABW        Aruba  1963  12178.107
# 4          ABW        Aruba  1964  11840.743

# %% [markdown]
# 웹상의 csv 파일도 쉽게 불러올 수 있습니다.

# %%
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
df2 = pd.read_csv(url, header=None)

# %%
df2.head()
# Out:
#      0    1    2    3            4
# 0  5.1  3.5  1.4  0.2  Iris-setosa
# 1  4.9  3.0  1.4  0.2  Iris-setosa
# 2  4.7  3.2  1.3  0.2  Iris-setosa
# 3  4.6  3.1  1.5  0.2  Iris-setosa
# 4  5.0  3.6  1.4  0.2  Iris-setosa

# %% [markdown]
# 데이터를 불러온 후에는 데이터타입이 맞게 불러들여졌는지 확인하세요.
#
# 숫자가 object라고 인식되어있으면 문자로 인식된 것으로 연산이 안됩니다

# %%
df.dtypes
# Out:
# country_code     object
# country_name     object
# year              int64
# value           float64
# dtype: object

# %% [markdown]
# 2. 데이터 전처리에 필요한 기능이 다양하게 제공되며, matplotlib 기반의 시각화를 지원합니다

# %%
df.describe()
# Out:
#                year         value
# count  13953.000000  1.395300e+04
# mean    1990.732316  8.254983e+05
# std       17.187585  2.788923e+06
# min     1960.000000 -8.067400e+01
# 25%     1976.000000  1.100000e+03
# 50%     1992.000000  1.390000e+04
# 75%     2006.000000  1.642779e+05
# max     2019.000000  3.434401e+07

# %%
# 특정 조건 가져오기
df.query('country_name=="Aruba"')
# Out:
#    country_code country_name  year      value
# 0           ABW        Aruba  1960  11092.675
# 1           ABW        Aruba  1961  11576.719
# 2           ABW        Aruba  1962  12713.489
# 3           ABW        Aruba  1963  12178.107
# 4           ABW        Aruba  1964  11840.743
# 5           ABW        Aruba  1965  10623.299
# 6           ABW        Aruba  1966   9933.903
# 7           ABW        Aruba  1967  12236.779
# 8           ABW        Aruba  1968  11378.701
# 9           ABW        Aruba  1969  14891.687
# 10          ABW        Aruba  1970  16655.514
# 11          ABW        Aruba  1971  14495.651
# 12          ABW        Aruba  1972  14055.611
# 13          ABW        Aruba  1973  15592.084
# 14          ABW        Aruba  1974  14132.618
# 15          ABW        Aruba  1975  10234.597
# 16          ABW        Aruba  1976  21862.654
# 17          ABW        Aruba  1977  11419.038
# 18          ABW        Aruba  1978   9724.884
# ...

# %%
# 어떤 데이터값이 있는지 확인
df.country_name.unique()
# Out:
# array(['Aruba', 'Africa Eastern and Southern', 'Afghanistan',
#        'Africa Western and Central', 'Angola', 'Albania', 'Andorra',
#        'Arab World', 'United Arab Emirates', 'Argentina', 'Armenia',
#        'Antigua and Barbuda', 'Australia', 'Austria', 'Azerbaijan',
#        'Burundi', 'Belgium', 'Benin', 'Burkina Faso', 'Bangladesh',
#        'Bulgaria', 'Bahrain', 'Bahamas, The', 'Bosnia and Herzegovina',
#        'Belarus', 'Belize', 'Bermuda', 'Bolivia', 'Brazil', 'Barbados',
#        'Brunei Darussalam', 'Bhutan', 'Botswana',
#        'Central African Republic', 'Canada',
#        'Central Europe and the Baltics', 'Switzerland', 'Chile', 'China',
#        "Cote d'Ivoire", 'Cameroon', 'Congo, Dem. Rep.', 'Congo, Rep.',
#        'Colombia', 'Comoros', 'Cabo Verde', 'Costa Rica',
#        'Caribbean small states', 'Cuba', 'Curacao', 'Cayman Islands',
#        'Cyprus', 'Czechia', 'Germany', 'Djibouti', 'Dominica', 'Denmark',
#        'Dominican Republic', 'Algeria',
# ...

# %% [markdown]
# 특정 조건으로 필터링 가능

# %%
df['country_name'].str.contains("korea", case=False)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 13948    False
# 13949    False
# 13950    False
# 13951    False
# 13952    False
# Name: country_name, Length: 13953, dtype: bool

# %% [markdown]
# df[] 괄호 안에 True, False를 넣게되면 True인 경우만 선택됩니다. 이를 활용해서 위의 결과가 참인 경우만 출력해봅시다

# %%
kor=df[df['country_name'].str.contains("korea", case=False)]
kor
# Out:
#       country_code               country_name  year         value
# 6709           KOR                Korea, Rep.  1960  12552.141000
# 6710           KOR                Korea, Rep.  1961  14462.648000
# 6711           KOR                Korea, Rep.  1962  17278.904000
# 6712           KOR                Korea, Rep.  1963  21103.585000
# 6713           KOR                Korea, Rep.  1964  22218.353000
# ...            ...                        ...   ...           ...
# 10245          PRK  Korea, Dem. People's Rep.  2015  25100.000381
# 10246          PRK  Korea, Dem. People's Rep.  2016  30000.000000
# 10247          PRK  Korea, Dem. People's Rep.  2017  54290.000916
# 10248          PRK  Korea, Dem. People's Rep.  2018  50529.998779
# 10249          PRK  Korea, Dem. People's Rep.  2019  56040.000916
#
# [120 rows x 4 columns]

# %%
south_kor = kor.query('country_code=="KOR"')

# %%
south_kor.dtypes
# Out:
# country_code     object
# country_name     object
# year              int64
# value           float64
# dtype: object

# %%
import matplotlib.pyplot as plt

plt.plot(south_kor['year'], south_kor['value'])
